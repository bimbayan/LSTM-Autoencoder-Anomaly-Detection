# %%
import os
os.chdir(r"C:\Users\bimba\.vscode\LSTM Autoencoder Project")

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\bimba\.vscode\LSTM Autoencoder Project\megamassign\NAB-master\data\realKnownCause\ambient_temperature_system_failure.csv")
data['timestamp'] = pd.to_datetime(data['timestamp'])
data = data.sort_values(by='timestamp')

plt.figure(figsize=(12,5)) #12 inches wide, 5 inches tall 
plt.plot(data['timestamp'], data['value'], label='Temperature')
plt.title('Ambient Temperature Over Time')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.show()
